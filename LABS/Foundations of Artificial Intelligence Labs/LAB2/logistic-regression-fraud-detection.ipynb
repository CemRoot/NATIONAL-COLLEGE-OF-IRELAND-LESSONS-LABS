# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
# Read in the data from the CSV file
df = pd.read_csv('./payment_fraud.csv')

# %%
df.sample(30)
# Out:
#        accountAgeDays  numItems  localTime paymentMethod  \
# 7363             2000         1   4.745402    creditcard
# 18004             631         1   4.836982    creditcard
# 273               989         1   4.836982    creditcard
# 5487             2000         1   4.748314        paypal
# 22552            2000         1   4.745402    creditcard
# 819                13         1   4.748314    creditcard
# 3329             2000         1   4.745402    creditcard
# 27154             161         1   4.742303        paypal
# 36197             349         1   4.836982    creditcard
# 4702             2000         1   4.876771        paypal
# 1488              155         1   5.040929        paypal
# 4140                1         1   4.921318    creditcard
# 10686              23         1   4.748314    creditcard
# 26820              19         1   4.748314        paypal
# 28290             219         1   5.017904    creditcard
# 15750               2         1   3.954522    creditcard
# 33128             168         1   4.876771    creditcard
# 6705             2000         1   4.524580   storecredit
# 17975              68         1   4.895263        paypal
# 4888             1881         1   5.017904        paypal
# 4542             2000         1   4.836982    creditcard
# 37385             476         1   4.524580    creditcard
# 5472               80         1   4.886641        paypal
# 18963             112         1   4.921349    creditcard
# 36251            1662         1   4.748314    creditcard
# 30484               5         1   5.017904   storecredit
# 2285             2000         1   4.742303    creditcard
# 27076            1331         1   4.962055    creditcard
# 14225             112         1   5.017904    creditcard
# 34001            2000         1   4.921318   storecredit
#
#        paymentMethodAgeDays  label
# 7363               0.000000      0
# 18004            178.624306      0
# 273              988.666667      0
# 5487             431.174306      0
# 22552            178.581944      0
# 819               12.040972      0
# 3329               4.131944      0
# 27154              0.000000      0
# 36197              0.021528      0
# 4702              77.153472      0
# 1488               0.000000      0
# 4140               0.000000      1
# 10686              0.000000      0
# 26820             18.106250      0
# 28290              0.000000      0
# 15750              1.140278      0
# 33128              0.000694      0
# 6705               0.000000      0
# 17975             67.019444      0
# 4888              84.966667      0
# 4542             401.965278      0
# 37385            106.639583      0
# 5472               0.000000      0
# 18963            111.829861      0
# 36251             25.630556      0
# 30484              0.000000      0
# 2285             453.427083      0
# 27076             84.065278      0
# 14225              0.000000      0
# 34001              0.000000      0

# %%
# Convert categorical feature into dummy variables with one-hot encoding
df = pd.get_dummies(df, columns=['paymentMethod'])
df.sample(3)
# Out:
#        accountAgeDays  numItems  localTime  paymentMethodAgeDays  label  \
# 355              1477         1   4.745402             64.606250      0
# 106              1547         1   4.962055              0.002083      0
# 13165            2000         1   4.921349              0.000000      0
#
#        paymentMethod_creditcard  paymentMethod_paypal  \
# 355                       False                  True
# 106                       False                  True
# 13165                      True                 False
#
#        paymentMethod_storecredit
# 355                        False
# 106                        False
# 13165                      False

# %%
# Split dataset up into train and test sets
X_train, X_test, y_train, y_test = train_test_split(
    df.drop('label', axis=1), df['label'],
    test_size=0.33, random_state=17)

# %%
# Initialize and train classifier model
clf = LogisticRegression().fit(X_train, y_train)

# Make predictions on test set
y_pred = clf.predict(X_test)

# %%
# Compare test set predictions with ground truth labels
print(accuracy_score(y_pred, y_test))
print(confusion_matrix(y_test, y_pred))
# Out:
# 1.0
# [[12753     0]
#  [    0   190]]
